# %% [markdown]
# ## LETS EXPLORE THE RAW DATA

# %%
# %sql
select * from salesdb.bronze.crm_raw

# %% [markdown]
# ## LETS CHECK ALL THE COLUMNS AND ITS DATATYPES

# %%
# %sql
describe salesdb.bronze.crm_raw
