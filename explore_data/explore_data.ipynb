# %% [markdown]
# ## Lets explore the raw data

# %%
df = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/Volumes/salesdb/bronze/sales_data_volume")
display(df)

# %% [markdown]
# ## Lets check all the columns and their datatypes

# %%
display(df.dtypes)
