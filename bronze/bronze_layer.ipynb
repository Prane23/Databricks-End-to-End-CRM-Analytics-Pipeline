# %% [markdown]
# ## Lets load raw data in to the bronze layer

# %%
# Path to your raw CSV
csv_path = "/Volumes/salesdb/bronze/sales_data_volume/crm_raw.csv"

df_raw =(
    spark.read.format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load(csv_path)
)
display(df_raw)

# %%
# %sql
drop table salesdb.bronze.crm_sales_data

# %% [markdown]
# ## Look like few column names have spaces in it , lets replace space with _ and save the table

# %%
df_raw = df_raw.toDF(*[col.strip().replace(" ", "_").replace("-", "_") for col in df.columns])
display(df_raw) 
df_raw.write.mode("overwrite").saveAsTable("salesdb.bronze.crm_sales_data")

# %% [markdown]
# ## lets check the data from table  crm_sales_data

# %%
# %sql
select * from salesdb.bronze.crm_sales_data
